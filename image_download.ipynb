# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/property_valuation
# Out:
# /content/drive/MyDrive/property_valuation

# %%
# !pip install requests tqdm

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/property_valuation/kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df[['price', 'lat', 'long']].isnull().sum()
# Out:
# price    0
# lat      0
# long     0
# dtype: int64

# %% [markdown]
# **Image Download Function**

# %%
# %%writefile scripts/data_fetcher.py

import os
import requests
import pandas as pd
from tqdm import tqdm

API_KEY = os.getenv("MAPS_API_KEY")

IMG_DIR = "images"
IMG_SIZE = "400x400"
ZOOM = 18

def fetch_image(lat, lon, save_path):
    url = (
        "https://maps.googleapis.com/maps/api/staticmap"
        f"?center={lat},{lon}"
        f"&zoom={ZOOM}"
        f"&size={IMG_SIZE}"
        f"&maptype=satellite"
        f"&key={API_KEY}"
    )
    r = requests.get(url)
    if r.status_code == 200:
        with open(save_path, "wb") as f:
            f.write(r.content)

def download_images(csv_path):
    df = pd.read_csv(csv_path)
    df = df.reset_index(drop=True)   # ⭐ FIX

    os.makedirs(IMG_DIR, exist_ok=True)

    for i, row in tqdm(df.iterrows(), total=len(df)):
        img_path = f"{IMG_DIR}/{i}.png"
        if not os.path.exists(img_path):
            fetch_image(row['lat'], row['long'], img_path)

if __name__ == "__main__":
    download_images("/content/drive/MyDrive/property_valuation/kc_house_data.csv")
# Out:
# Overwriting scripts/data_fetcher.py

# %%
# !rm -rf images
# !mkdir images

# %%
# !python scripts/data_fetcher.py
# Out:
# 100% 21613/21613 [05:19<00:00, 67.73it/s]

# %%
import os
import pandas as pd
import requests
from PIL import Image
from tqdm import tqdm

# Load CSV
df = pd.read_csv("/content/drive/MyDrive/property_valuation/kc_house_data.csv")

# Ensure images folder exists
os.makedirs("images", exist_ok=True)

# Example download loop (for first few images)
for idx, row in tqdm(df.iterrows(), total=len(df)):
    img_path = f"images/{idx}.png"
    if not os.path.exists(img_path):
        # Replace this with your actual image fetching API
        image = Image.new("RGB", (224,224))  # placeholder
        image.save(img_path)
# Out:
# 100%|██████████| 21613/21613 [05:16<00:00, 68.27it/s]

# %%
# !ls images | head -10
# Out:
# 0.png
# 10000.png
# 10001.png
# 10002.png
# 10003.png
# 10004.png
# 10005.png
# 10006.png
# 10007.png
# 10008.png
